# %% [markdown]
# # Introduction
# In this notebook we will test the tuned implementation of Alexnet on the "hot dog" dataset. For the author's original discussion of the subject, see [here](https://kratzert.github.io/2017/02/24/finetuning-alexnet-with-tensorflow.html).
#
# To run this notebook you have to download the `bvlc_alexnet.npy` file from [here](http://www.cs.toronto.edu/~guerzhoy/tf_alexnet/), which stores the pretrained weights for AlexNet.
#
# This notebook was originally written by Frederik Kratzert, and has been modified by George Gu. If errors are encountered in the last cell, please restart the kernel and try again.

# %%
#some basic imports and setups
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

#mean of imagenet dataset in BGR
imagenet_mean = np.array([104., 117., 124.], dtype=np.float32)

image_dir = 'data/hot_dog/test'

# %matplotlib inline

# %%
#get list of all images
img_files = [os.path.join(image_dir, f) for f in os.listdir(image_dir) if f.endswith('.jpg')]

#load all images
imgs = []
for f in img_files:
    imgs.append(cv2.imread(f))
    
#plot images
fig = plt.figure(figsize=(15,6))
for i, img in enumerate(imgs):
    fig.add_subplot(3,3,i+1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')

# %% [markdown]
# First we will create placeholder for the dropout rate and the inputs and create an AlexNet object. Then we will link the activations from the last layer to the variable `score` and define an op to calculate the softmax values.

# %%
import sys
sys.path.append('code')
from alexnet import AlexNet
from hd_classes import class_names

#placeholder for input and dropout rate
x = tf.placeholder(tf.float32, [1, 256, 256, 3])
keep_prob = tf.placeholder(tf.float32)

#create model with default config ( == no skip_layer and 1000 units in the last layer)
model = AlexNet(x, keep_prob, 2, [])

#define activation of last layer as score
score = model.fc8

#create op to calculate softmax 
softmax = tf.nn.softmax(score)

# %% [markdown]
# Now we will start a TensorFlow session and load pretrained weights into the layer weights. Then we will loop over all images and calculate the class probability for each image and plot the image again, together with the predicted class and the corresponding class probability.

# %%
with tf.Session() as sess:
    
    # Initialize all variables
    sess.run(tf.global_variables_initializer())
    
    # Load tuned weights into the model
    saver = tf.train.Saver()
    saver.restore(sess, "data/hd_checkpoints/model_epoch10.ckpt")
    
    # Create figure handle
    fig2 = plt.figure(figsize=(15,6))
    
    # Loop over all images
    for i, image in enumerate(imgs):
        
        # Convert image to float32 and resize to (256x256)
        img = cv2.resize(image.astype(np.float32), (256,256))
        
        # Subtract the ImageNet mean
        img -= imagenet_mean
        
        # Reshape as needed to feed into model
        img = img.reshape((1,256,256,3))
        
        # Run the session and calculate the class probability
        probs = sess.run(softmax, feed_dict={x: img, keep_prob: 1})
        
        # Get the class name of the class with the highest probability
        class_name = class_names[np.argmax(probs)]
        
        # Plot image with class name and prob in the title
        fig2.add_subplot(3,3,i+1)
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        plt.title("Class: " + class_name + ", probability: %.4f" %probs[0,np.argmax(probs)])
        plt.axis('off')
# Out:
# INFO:tensorflow:Restoring parameters from data/hd_checkpoints/model_epoch10.ckpt

# %% [markdown]
# Below, we will test the tuning of Alextnet for the 101 Objects set. This will be done by selecting 9 images at random from the test pool, as specified in @te_list.txt. Please note that this text file was modified using some basic regex in order to function properly with the code below.

# %%
# Test of 101 Objects Data Set
#some basic imports and setups
import os
import cv2
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# Mean of imagenet dataset in BGR
imagenet_mean = np.array([104., 117., 124.], dtype=np.float32)

te_text = open('data/101_obj/@te_list.txt')

te_list = te_text.readlines()
te_list = [x.replace('\n', '') for x in te_list]
te_selection = []

for i in range(9):
    te_selection.append(random.choice(te_list))
    
#load all images
imgs = []
for image in te_selection:
    imgs.append(cv2.imread(image))
    
#plot images
fig = plt.figure(figsize=(15,6))
for i, img in enumerate(imgs):
    fig.add_subplot(3,3,i+1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')

# %%
#placeholder for input and dropout rate
x = tf.placeholder(tf.float32, [1, 256, 256, 3])
keep_prob = tf.placeholder(tf.float32)

#create model with default config ( == no skip_layer and 1000 units in the last layer)
model = AlexNet(x, keep_prob, 2, [])

#define activation of last layer as score
score = model.fc8

#create op to calculate softmax 
softmax = tf.nn.softmax(score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-98b16de44351> in <module>()
#       4
#       5 #create model with default config ( == no skip_layer and 1000 units in the last layer)
# ----> 6 model = AlexNet(x, keep_prob, 2, [])
#       7
#       8 #define activation of last layer as score
#
# ~/Documents/tune-alexnet/code/alexnet.py in __init__(self, x, keep_prob, num_classes, skip_layer, weights_path)
#      54
#      55         # Call the create function to build the computational graph of AlexNet
# ---> 56         self.create()
#      57
#      58     def create(self):
#
# ~/Documents/tune-alexnet/code/alexnet.py in create(self)
#      59         """Create the network graph."""
#      60         # 1st Layer: Conv (w ReLu) -> Lrn -> Pool
# ---> 61         conv1 = conv(self.X, 11, 11, 96, 4, 4, padding='VALID', name='conv1')
# ...

# %%
with tf.Session() as sess:
    
    # Initialize all variables
    sess.run(tf.global_variables_initializer())
    
    # Load tuned weights into the model
    saver = tf.train.Saver()
    saver.restore(sess, "data/hd_checkpoints/model_epoch10.ckpt")
    
    # Create figure handle
    fig2 = plt.figure(figsize=(15,6))
    
    # Loop over all images
    for i, image in enumerate(imgs):
        
        # Convert image to float32 and resize to (256x256)
        img = cv2.resize(image.astype(np.float32), (256,256))
        
        # Subtract the ImageNet mean
        img -= imagenet_mean
        
        # Reshape as needed to feed into model
        img = img.reshape((1,256,256,3))
        
        # Run the session and calculate the class probability
        probs = sess.run(softmax, feed_dict={x: img, keep_prob: 1})
        
        # Get the class name of the class with the highest probability
        class_name = class_names[np.argmax(probs)]
        
        # Plot image with class name and prob in the title
        fig2.add_subplot(3,3,i+1)
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        plt.title("Class: " + class_name + ", probability: %.4f" %probs[0,np.argmax(probs)])
        plt.axis('off')
